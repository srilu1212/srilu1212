# %% [markdown]
# <a href="https://colab.research.google.com/github/srilu1212/srilu1212/blob/main/Course_0C_Programming_and_Mathematics_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.0.2

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.0.2

# %% [markdown]
# #python

# %% [markdown]
# ## Numeric - int, float, complex
# Sequence Type - string, list, tuple
# Mapping Type - dict
# Boolean - bool
# Set Type - set, frozenset
# Binary Types - bytes, bytearray, memoryview

# %% [markdown]
# let's take two variables,**a** and *b*, and find their sum and product

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 2
b = 3

# %% [markdown]
# ##sum

# %%
c = a + b

# %% [markdown]
# ##product

# %%
d = a * b

# %%
c
# Out:
# 5

# %%
d
# Out:
# 6

# %%
e = 4
f = 5
g = e + f
h = e * f

# %%
g
# Out:
# 9

# %%
h
# Out:
# 20

# %% [markdown]
# #Numerics

# %%
k = 1
a=3.14

# %% [markdown]
# ##Integers (int):
# Integers represent whole numbers without any fractional part.
# They can be positive, negative, or zero (e.g., 5, -10, 0).

# %%
type(a)
# Out:
# float

# %%
num1 = 1
num2 = 3.14

# %% [markdown]
# ##Floats

# %% [markdown]
# ##Floats, or floating-point numbers, represent numbers that have a fractional part, even if that fractional part is zero (e.g., 3.14, -0.5, 2.0).

# %%
type(num1)
type(num2)
# Out:
# float

# %%
negative_num = -3

# %%
negative_num
# Out:
# -3

# %%
type(negative_num)
# Out:
# int

# %%
x , y , z = 2 ,3 , 4

# %%
x
# Out:
# 2

# %%
a = 1

b = c = -2  # assigns -2 to both b and c

x,y,z = 3.0, 4, -5.0

# %%
# assigns the values 3.0, 4, and -5.0 to x, y, and z respectively
x
# Out:
# 3.0

# %%
y
# Out:
# 4

# %%
z
# Out:
# -5.0

# %%
number = 0.0
Number = -999

# %%
number
# Out:
# 0.0

# %%
Number
# Out:
# -999

# %%
a = 0.0

# %%
type(a)
# Out:
# float

# %%
a = 1

b = 2

c = 3

a, b, c = 4, 5, 6

a = c = 7

# %%
a
# Out:
# 7

# %%
b
# Out:
# 5

# %%
c
# Out:
# 7

# %% [markdown]
# #Strings
#
# ```
# ##Strings are created by enclosing a sequence of characters within:
# Single quotes: 'hello'
# Double quotes: "world"
# ```

# %%
my_str = 'Hello world!'

# %%
print(my_str)
# Out:
# Hello world!

# %%
'abc'
' '
'123'
'$%^'
'abc 123$%^'
# Out:
# 'abc 123$%^'

# %%
my_str = 'abc'
my_str = "abc"

# %%
int('3')
float('3.14')
# Out:
# 3.14

# %%
float(42)
int(-0.001)
# Out:
# 0

# %%
str(12345)
# Out:
# '12345'

# %%
#int('3.14')
#float('abc')
#int('abc')

# %%
float('3.14')
# float('abc') # This would cause a ValueError
# int('abc') # This would cause a ValueError
# Out:
# 3.14

# %%
a = 3.14

# %%
answer = str(int(a))
print (answer)
# Out:
# 3

# %%
  age = 30
  age
# Out:
# 30

# %% [markdown]
# #Variables

# %% [markdown]
# ###Variables of the boolean data type are used to store one of two values: True or False. Booleans are crucial in programming because they enable us to perform all kinds of logical operations. At the lowest level of code, a machine thinks in terms of ones and zeroes (binary). This is the same as saying “yes” and “no” or True and False.

# %%
a = True
b = False

# %%
int(True)  # output: 1
# Out:
# 1

# %%
float(True)  # output: 1.0
# Out:
# 1.0

# %%
str(True)  # output: ‘True’
# Out:
# 'True'

# %%
str(False)  # output: ‘False’
# Out:
# 'False'

# %%
int(True)  # output: ‘1’
# Out:
# 1

# %%
int(False)  # output: ‘0’
# Out:
# 0

# %%
bool(1)  # output: ‘True’
# Out:
# True

# %%
bool()  # output: ‘False’
# Out:
# False

# %%
bool(0)  # output: ‘False’
# Out:
# False

# %%
bool(1)  # output: True
# Out:
# True

# %%
bool(0)  # output: False
# Out:
# False

# %%
bool(0.002)
# Out:
# True

# %%
bool(-0.002)
# Out:
# True

# %%
bool(-1)  # output: True
# Out:
# True

# %%
bool('') # output: ‘False’
# Out:
# False

# %%
bool("") # output: ‘False’
# Out:
# False

# %%
bool('Hello') # output: ‘False’
# Out:
# True

# %%
a = 4 # integer
b = 4.5 # float
c = 4j # complex number

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# ##Input and Output

# %%
user_input = input()

# %%
user_input

# %%
print(1)
print('abc')

# %%
user_input = input('Please enter a positive number: ')
